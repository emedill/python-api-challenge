# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import json 

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0        katsuura  35.1333  140.3000    289.55        71         100
# 1        1          ndende  -2.4008   11.3581    296.87        97          53
# 2        2       ketchikan  55.3422 -131.6461    289.41        39           0
# 3        3  puerto natales -51.7236  -72.4875    276.76        87          94
# 4        4       miasskoye  55.2784   61.8905    275.64        70          50
#
#    Wind Speed Country        Date
# 0        4.80      JP  1683754031
# 1        0.66      GA  1683754032
# 2        6.69      US  1683754033
# 3        0.51      CL  1683754034
# 4        2.10      RU  1683754035

# %%
print(city_data_df['Cloudiness'].describe())
# Out:
# count    587.000000
# mean      55.466780
# std       38.638919
# min        0.000000
# 25%       17.000000
# 50%       65.000000
# 75%       96.500000
# max      100.000000
# Name: Cloudiness, dtype: float64

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
city_map= city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 600,
    frame_height = 500,
    size = "Humidity",
    scale = 0.7,
    color = "City"
)

# Display the map
city_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Rename the Max Temp column to Max Temp Kelvin 
city_data_df.rename(columns={"Max Temp": "Max Temp Kelvin"}, inplace=True)

# Convert the temperature from Kelvin to Celsius
city_data_df["Max Temp Celsius"] = city_data_df["Max Temp Kelvin"] - 273.15

# Narrow down cities that fit criteria and drop any results with null values
filtered_city_data_df = city_data_df[
    (city_data_df["Max Temp Celsius"] > 23) & (city_data_df["Max Temp Celsius"] < 29) &
    (city_data_df["Humidity"] < 75) &
    (city_data_df["Cloudiness"] ==0)
    ]

# Drop any rows with null values
filtered_city_data_df.dropna(inplace=True)

# Display sample data
filtered_city_data_df
# Out:
# C:\Users\19517\AppData\Local\Temp\ipykernel_17184\81571320.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_city_data_df.dropna(inplace=True)
#      City_ID                City      Lat       Lng  Max Temp Kelvin  \
# 9          9              bethel  41.3712  -73.4140           296.49
# 47        47              at taj  24.2049   23.2857           297.18
# 53        53   wailua homesteads  22.0669 -159.3780           299.39
# 79        79       marsh harbour  26.5412  -77.0636           298.94
# 83        83          fort bragg  35.1390  -79.0060           299.23
# 149      149               lihue  21.9789 -159.3672           299.73
# 152      152              kapa'a  22.0752 -159.3190           300.14
# 200      200            qaisumah  28.3112   46.1273           301.13
# 222      222           nathdwara  24.9333   73.8167           301.80
# 293      293              elkins  38.9259  -79.8467           297.38
# 296      296             cambria  35.5641 -121.0808           296.41
# 309      309      hassi messaoud  31.6804    6.0729           300.07
# 311      311         les avirons -21.2418   55.3394           296.18
# 329      329            hamilton  39.1834  -84.5333           299.13
# 337      337               oasis  33.4659 -116.0989           301.67
# 393      393              waseca  44.0777  -93.5074           299.36
# 411      411              illizi  26.4833    8.4667           298.04
# 470      470       harrisonville  38.6533  -94.3488           302.10
# 526      526       cooper's town  26.8667  -77.5167           298.40
# 529      529  comstock northwest  42.3218  -85.5176           298.21
# 533      533             douglas  41.3000  -96.1670           301.79
# 538      538      mount pleasant  32.7941  -79.8626           301.23
# 552      552       fuquay-varina  35.5843  -78.8000           299.33
nearest hotel: No hotel found
# wailua homesteads - nearest hotel: Hilton Garden Inn Kauai Wailua Bay
# marsh harbour - nearest hotel: Lofty Fig Villas
# fort bragg - nearest hotel: Airborne Inn Lodging
# lihue - nearest hotel: Kauai Palms
# kapa'a - nearest hotel: Pono Kai Resort
# qaisumah - nearest hotel: No hotel found
# nathdwara - nearest hotel: Hotel Sagar and Restaurant
# elkins - nearest hotel: Holiday Inn Express Inn and Suites
# cambria - nearest hotel: Olallieberry Inn
# hassi messaoud - nearest hotel: AMC
# les avirons - nearest hotel: Floralys
# hamilton - nearest hotel: North Vista Manor
# oasis - nearest hotel: No hotel found
# waseca - nearest hotel: GrandStay Hotel & Suites
# illizi - nearest hotel: بوناقة
# harrisonville - nearest hotel: Knights Inn Harrisonville
# cooper's town - nearest hotel: No hotel found
# comstock northwest - nearest hotel: Radisson Plaza Hotel at Kalamazoo Center
# douglas - nearest hotel: Residence Inn Omaha West
# mount pleasant - nearest hotel: Old Village Post House
# fuquay-varina - nearest hotel: Quality Inn
#                    City Country      Lat       Lng  Humidity  \
# 9                bethel      US  41.3712  -73.4140        30
# 47               at taj      LY  24.2049   23.2857        25
# 53    wailua homesteads      US  22.0669 -159.3780        67
# 79        marsh harbour      BS  26.5412  -77.0636        61
# 83           fort bragg      US  35.1390  -79.0060        32
# 149               lihue      US  21.9789 -159.3672        67
# 152              kapa'a      US  22.0752 -159.3190        67
# 200            qaisumah      SA  28.3112   46.1273        36
# 222           nathdwara      IN  24.9333   73.8167        19
# 293              elkins      US  38.9259  -79.8467        36
# 296             cambria      US  35.5641 -121.0808        74
# 309      hassi messaoud      DZ  31.6804    6.0729        26
# 311         les avirons      RE -21.2418   55.3394        73
# 329            hamilton      US  39.1834  -84.5333        31
# 337               oasis      US  33.4659 -116.0989        26
# 393              waseca      US  44.0777  -93.5074        47
# 411              illizi      DZ  26.4833    8.4667        28
# 470       harrisonville      US  38.6533  -94.3488        51
# 526       cooper's town      BS  26.8667  -77.5167        65
# 529  comstock northwest      US  42.3218  -85.5176        27
# 533             douglas      US  41.3000  -96.1670        52
# 538      mount pleasant      US  32.7941  -79.8626        65
# 552       fuquay-varina      US  35.5843  -78.8000        38
#
#                                    Hotel Name
# 9                         Hampton Inn Danbury
# 47                             No hotel found
# 53         Hilton Garden Inn Kauai Wailua Bay
# 79                           Lofty Fig Villas
# 83                       Airborne Inn Lodging
# 149                               Kauai Palms
# 152                           Pono Kai Resort
# 200                            No hotel found
# 222                Hotel Sagar and Restaurant
# 293        Holiday Inn Express Inn and Suites
# 296                          Olallieberry Inn
# 309                                       AMC
# 311                                  Floralys
# 329                         North Vista Manor
# 337                            No hotel found
# 393                  GrandStay Hotel & Suites
# 411                                    بوناقة
# 470                 Knights Inn Harrisonville
# 526                            No hotel found
# 529  Radisson Plaza Hotel at Kalamazoo Center
# 533                  Residence Inn Omaha West
# 538                    Old Village Post House
# 552                               Quality Inn

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
hotel_map= hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 600,
    frame_height = 500,
    scale = 0.7,
    color = "City",
    hover_cols= ["Hotel Name", "Country"]
)

# Display the map
hotel_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Hotel Name,Country)
